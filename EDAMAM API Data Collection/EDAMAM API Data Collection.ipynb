# %% [markdown]
# # Goal

# %%
# The goal of this project is to demonstrate skills in collecting data from APIs that require authentication and POST requests.

# %%
# This project will be collecting data from EDAMAM's Nutrition Analysis API.
# Documentation: https://developer.edamam.com/edamam-docs-nutrition-api

# %%
# Importing necessary modules
import requests
import json

# %% [markdown]
# # Constructing our Request

# %%
# Specify base route

base_url = "https://api.edamam.com/api/nutrition-details"

# %%
# Specifying the necessary headers (found in documentation)

headers = {
    'Content-Type': 'application/json'
}

# %%
# Specifying the App ID and App Key

# NOTE: These are my personal app_id and app_key obtained upon registration.
# EDAMAM has a limit to how many requests can be made by a free account in a period of time.
# PLEASE DO NOT USE THESE FOR YOUR OWN USE WITHOUT MY PERMISSION.

params = {
    "app_id" : "749011cb",
    "app_key" : "ed614cd1332168eaaf098a1d338a474b"
}

# %%
# Specifying the body we will send with our POST request (see EDAMAM Nutrition Analysis API documentation)

body = {
    
    # The title of our recipe
    "title" : "Rice, Beans, and Salmon",
    
    # The unstructured text containing recipe ingredients
    "ingr" : [ 
        "100g cooked basmati rice",
        "100g cooked black beans",
        "100g cooked salmon"
    ]
}

# %% [markdown]
# # Sending our Request

# %%
response = requests.post(url=base_url, headers=headers, params=params, json=body)
response.status_code
# Out:
# 200

# %%
# Storing our response JSON
r = response.json()

# %% [markdown]
# # Inspecting the Structure of our Response

# %%
print(json.dumps(r, indent=4))
# Out:
# {
#     "uri": "http://www.edamam.com/ontologies/edamam.owl#recipe_61eff58fa41a4c28a2e66acafabe7397",
#     "yield": 4.0,
#     "calories": 470,
#     "totalWeight": 300.0,
#     "dietLabels": [
#         "LOW_SODIUM"
#     ],
#     "healthLabels": [
#         "SUGAR_CONSCIOUS",
#         "KIDNEY_FRIENDLY",
#         "PESCATARIAN",
#         "MEDITERRANEAN",
#         "DASH",
#         "DAIRY_FREE",
#         "GLUTEN_FREE",
#         "WHEAT_FREE",
#         "EGG_FREE",
#         "MILK_FREE",
#         "PEANUT_FREE",
#         "TREE_NUT_FREE",
#         "SOY_FREE",
#         "SHELLFISH_FREE",
#         "PORK_FREE",
#         "RED_MEAT_FREE",
#         "CRUSTACEAN_FREE",
#         "CELERY_FREE",
#         "MUSTARD_FREE",
#         "SESAME_FREE",
#         "LUPINE_FREE",
#         "MOLLUSK_FREE",
#         "ALCOHOL_FREE",
#         "NO_OIL_ADDED",
#         "NO_SUGAR_ADDED",
#         "SULPHITE_FREE"
#     ],
#     "cautions": [],
#     "totalNutrients": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 470.0,
#             "unit": "kcal"
#         },
#         "FAT": {
#             "label": "Total lipid (fat)",
#             "quantity": 14.24,
#             "unit": "g"
#         },
#         "FASAT": {
#             "label": "Fatty acids, total saturated",
#             "quantity": 3.266,
#             "unit": "g"
#         },
#         "FAMS": {
#             "label": "Fatty acids, total monounsaturated",
#             "quantity": 3.9050000000000002,
#             "unit": "g"
#         },
#         "FAPU": {
#             "label": "Fatty acids, total polyunsaturated",
#             "quantity": 4.1930000000000005,
#             "unit": "g"
#         },
#         "CHOCDF": {
#             "label": "Carbohydrate, by difference",
#             "quantity": 51.88,
#             "unit": "g"
#         },
#         "FIBTG": {
#             "label": "Fiber, total dietary",
#             "quantity": 9.1,
#             "unit": "g"
#         },
#         "SUGAR": {
#             "label": "Sugars, total",
#             "quantity": 0.05,
#             "unit": "g"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 31.97,
#             "unit": "g"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 55.0,
#             "unit": "mg"
#         },
#         "NA": {
#             "label": "Sodium, Na",
#             "quantity": 61.0,
#             "unit": "mg"
#         },
#         "CA": {
#             "label": "Calcium, Ca",
#             "quantity": 46.0,
#             "unit": "mg"
#         },
#         "MG": {
#             "label": "Magnesium, Mg",
#             "quantity": 109.0,
#             "unit": "mg"
#         },
#         "K": {
#             "label": "Potassium, K",
#             "quantity": 753.0,
#             "unit": "mg"
#         },
#         "FE": {
#             "label": "Iron, Fe",
#             "quantity": 3.6399999999999997,
#             "unit": "mg"
#         },
#         "ZN": {
#             "label": "Zinc, Zn",
#             "quantity": 1.9700000000000002,
#             "unit": "mg"
#         },
#         "P": {
#             "label": "Phosphorus, P",
#             "quantity": 423.0,
#             "unit": "mg"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A, RAE",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "VITC": {
#             "label": "Vitamin C, total ascorbic acid",
#             "quantity": 3.9,
#             "unit": "mg"
#         },
#         "THIA": {
#             "label": "Thiamin",
#             "quantity": 0.614,
#             "unit": "mg"
#         },
#         "RIBF": {
#             "label": "Riboflavin",
#             "quantity": 0.22699999999999998,
#             "unit": "mg"
#         },
#         "NIA": {
#             "label": "Niacin",
#             "quantity": 10.653,
#             "unit": "mg"
#         },
#         "VITB6A": {
#             "label": "Vitamin B-6",
#             "quantity": 0.798,
#             "unit": "mg"
#         },
#         "FOLDFE": {
#             "label": "Folate, DFE",
#             "quantity": 272.0,
#             "unit": "\u00b5g"
#         },
#         "FOLFD": {
#             "label": "Folate, food",
#             "quantity": 178.0,
#             "unit": "\u00b5g"
#         },
#         "FOLAC": {
#             "label": "Folic acid",
#             "quantity": 55.0,
#             "unit": "\u00b5g"
#         },
#         "VITB12": {
#             "label": "Vitamin B-12",
#             "quantity": 3.23,
#             "unit": "\u00b5g"
#         },
#         "VITD": {
#             "label": "Vitamin D (D2 + D3)",
#             "quantity": 0.0,
#             "unit": "\u00b5g"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E (alpha-tocopherol)",
#             "quantity": 3.59,
#             "unit": "mg"
#         },
#         "VITK1": {
#             "label": "Vitamin K (phylloquinone)",
#             "quantity": 0.5,
#             "unit": "\u00b5g"
#         },
#         "WATER": {
#             "label": "Water",
#             "quantity": 199.07,
#             "unit": "g"
#         }
#     },
#     "totalDaily": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 23.5,
#             "unit": "%"
#         },
#         "FAT": {
#             "label": "Fat",
#             "quantity": 21.907692307692308,
#             "unit": "%"
#         },
#         "FASAT": {
#             "label": "Saturated",
#             "quantity": 16.330000000000002,
#             "unit": "%"
#         },
#         "CHOCDF": {
#             "label": "Carbs",
#             "quantity": 17.293333333333333,
#             "unit": "%"
#         },
#         "FIBTG": {
#             "label": "Fiber",
#             "quantity": 36.4,
#             "unit": "%"
#         },
#         "PROCNT": {
#             "label": "Protein",
#             "quantity": 63.94,
#             "unit": "%"
#         },
#         "CHOLE": {
#             "label": "Cholesterol",
#             "quantity": 18.333333333333332,
#             "unit": "%"
#         },
#         "NA": {
#             "label": "Sodium",
#             "quantity": 2.5416666666666665,
#             "unit": "%"
#         },
#         "CA": {
#             "label": "Calcium",
#             "quantity": 4.6,
#             "unit": "%"
#         },
#         "MG": {
#             "label": "Magnesium",
#             "quantity": 25.952380952380953,
#             "unit": "%"
#         },
#         "K": {
#             "label": "Potassium",
#             "quantity": 16.02127659574468,
#             "unit": "%"
#         },
#         "FE": {
#             "label": "Iron",
#             "quantity": 20.222222222222218,
#             "unit": "%"
#         },
#         "ZN": {
#             "label": "Zinc",
#             "quantity": 17.90909090909091,
#             "unit": "%"
#         },
#         "P": {
#             "label": "Phosphorus",
#             "quantity": 60.42857142857143,
#             "unit": "%"
#         },
#         "VITA_RAE": {
#             "label": "Vitamin A",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "VITC": {
#             "label": "Vitamin C",
#             "quantity": 4.333333333333333,
#             "unit": "%"
#         },
#         "THIA": {
#             "label": "Thiamin (B1)",
#             "quantity": 51.166666666666664,
#             "unit": "%"
#         },
#         "RIBF": {
#             "label": "Riboflavin (B2)",
#             "quantity": 17.46153846153846,
#             "unit": "%"
#         },
#         "NIA": {
#             "label": "Niacin (B3)",
#             "quantity": 66.58125,
#             "unit": "%"
#         },
#         "VITB6A": {
#             "label": "Vitamin B6",
#             "quantity": 61.384615384615394,
#             "unit": "%"
#         },
#         "FOLDFE": {
#             "label": "Folate equivalent (total)",
#             "quantity": 68.0,
#             "unit": "%"
#         },
#         "VITB12": {
#             "label": "Vitamin B12",
#             "quantity": 134.58333333333334,
#             "unit": "%"
#         },
#         "VITD": {
#             "label": "Vitamin D",
#             "quantity": 0.0,
#             "unit": "%"
#         },
#         "TOCPHA": {
#             "label": "Vitamin E",
#             "quantity": 23.933333333333334,
#             "unit": "%"
#         },
#         "VITK1": {
#             "label": "Vitamin K",
#             "quantity": 0.4166666666666667,
#             "unit": "%"
#         }
#     },
#     "totalNutrientsKCal": {
#         "ENERC_KCAL": {
#             "label": "Energy",
#             "quantity": 470,
#             "unit": "kcal"
#         },
#         "PROCNT_KCAL": {
#             "label": "Calories from protein",
#             "quantity": 130,
#             "unit": "kcal"
#         },
#         "FAT_KCAL": {
#             "label": "Calories from fat",
#             "quantity": 130,
#             "unit": "kcal"
#         },
#         "CHOCDF_KCAL": {
#             "label": "Calories from carbohydrates",
#             "quantity": 210,
#             "unit": "kcal"
#         }
#     }
# }

# %%
r.keys()
# Out:
# dict_keys(['uri', 'yield', 'calories', 'totalWeight', 'dietLabels', 'healthLabels', 'cautions', 'totalNutrients', 'totalDaily', 'totalNutrientsKCal'])

# %%
# For the sake of this project, we'll collect data on totalNutrients
recipe_nutrients = r["totalNutrients"]
print(json.dumps(recipe_nutrients, indent=4))

# We can see that each nutrient has a label, quantity, and unit for this recipe
# Out:
# {
#     "ENERC_KCAL": {
#         "label": "Energy",
#         "quantity": 470.0,
#         "unit": "kcal"
#     },
#     "FAT": {
#         "label": "Total lipid (fat)",
#         "quantity": 14.24,
#         "unit": "g"
#     },
#     "FASAT": {
#         "label": "Fatty acids, total saturated",
#         "quantity": 3.266,
#         "unit": "g"
#     },
#     "FAMS": {
#         "label": "Fatty acids, total monounsaturated",
#         "quantity": 3.9050000000000002,
#         "unit": "g"
#     },
#     "FAPU": {
#         "label": "Fatty acids, total polyunsaturated",
#         "quantity": 4.1930000000000005,
#         "unit": "g"
#     },
#     "CHOCDF": {
#         "label": "Carbohydrate, by difference",
#         "quantity": 51.88,
#         "unit": "g"
#     },
#     "FIBTG": {
#         "label": "Fiber, total dietary",
#         "quantity": 9.1,
#         "unit": "g"
#     },
#     "SUGAR": {
#         "label": "Sugars, total",
#         "quantity": 0.05,
#         "unit": "g"
#     },
#     "PROCNT": {
#         "label": "Protein",
#         "quantity": 31.97,
#         "unit": "g"
#     },
#     "CHOLE": {
#         "label": "Cholesterol",
#         "quantity": 55.0,
#         "unit": "mg"
#     },
#     "NA": {
#         "label": "Sodium, Na",
#         "quantity": 61.0,
#         "unit": "mg"
#     },
#     "CA": {
#         "label": "Calcium, Ca",
#         "quantity": 46.0,
#         "unit": "mg"
#     },
#     "MG": {
#         "label": "Magnesium, Mg",
#         "quantity": 109.0,
#         "unit": "mg"
#     },
#     "K": {
#         "label": "Potassium, K",
#         "quantity": 753.0,
#         "unit": "mg"
#     },
#     "FE": {
#         "label": "Iron, Fe",
#         "quantity": 3.6399999999999997,
#         "unit": "mg"
#     },
#     "ZN": {
#         "label": "Zinc, Zn",
#         "quantity": 1.9700000000000002,
#         "unit": "mg"
#     },
#     "P": {
#         "label": "Phosphorus, P",
#         "quantity": 423.0,
#         "unit": "mg"
#     },
#     "VITA_RAE": {
#         "label": "Vitamin A, RAE",
#         "quantity": 0.0,
#         "unit": "\u00b5g"
#     },
#     "VITC": {
#         "label": "Vitamin C, total ascorbic acid",
#         "quantity": 3.9,
#         "unit": "mg"
#     },
#     "THIA": {
#         "label": "Thiamin",
#         "quantity": 0.614,
#         "unit": "mg"
#     },
#     "RIBF": {
#         "label": "Riboflavin",
#         "quantity": 0.22699999999999998,
#         "unit": "mg"
#     },
#     "NIA": {
#         "label": "Niacin",
#         "quantity": 10.653,
#         "unit": "mg"
#     },
#     "VITB6A": {
#         "label": "Vitamin B-6",
#         "quantity": 0.798,
#         "unit": "mg"
#     },
#     "FOLDFE": {
#         "label": "Folate, DFE",
#         "quantity": 272.0,
#         "unit": "\u00b5g"
#     },
#     "FOLFD": {
#         "label": "Folate, food",
#         "quantity": 178.0,
#         "unit": "\u00b5g"
#     },
#     "FOLAC": {
#         "label": "Folic acid",
#         "quantity": 55.0,
#         "unit": "\u00b5g"
#     },
#     "VITB12": {
#         "label": "Vitamin B-12",
#         "quantity": 3.23,
#         "unit": "\u00b5g"
#     },
#     "VITD": {
#         "label": "Vitamin D (D2 + D3)",
#         "quantity": 0.0,
#         "unit": "\u00b5g"
#     },
#     "TOCPHA": {
#         "label": "Vitamin E (alpha-tocopherol)",
#         "quantity": 3.59,
#         "unit": "mg"
#     },
#     "VITK1": {
#         "label": "Vitamin K (phylloquinone)",
#         "quantity": 0.5,
#         "unit": "\u00b5g"
#     },
#     "WATER": {
#         "label": "Water",
#         "quantity": 199.07,
#         "unit": "g"
#     }
# }

# %%
recipe_nutrients.keys()
# Out:
# dict_keys(['ENERC_KCAL', 'FAT', 'FASAT', 'FAMS', 'FAPU', 'CHOCDF', 'FIBTG', 'SUGAR', 'PROCNT', 'CHOLE', 'NA', 'CA', 'MG', 'K', 'FE', 'ZN', 'P', 'VITA_RAE', 'VITC', 'THIA', 'RIBF', 'NIA', 'VITB6A', 'FOLDFE', 'FOLFD', 'FOLAC', 'VITB12', 'VITD', 'TOCPHA', 'VITK1', 'WATER'])

# %% [markdown]
# # Collecting our Data

# %%
# Creating separate lists for labels, quantities, and units
nutrient_labels = []
nutrient_quantities = []
nutrient_units = []
for key in recipe_nutrients.keys():
    nutrient = recipe_nutrients[key]
    nutrient_labels.append(nutrient["label"])
    nutrient_quantities.append(nutrient["quantity"])
    nutrient_units.append(nutrient["unit"])

# %%
nutrient_labels
# Out:
# ['Energy',
#  'Total lipid (fat)',
#  'Fatty acids, total saturated',
#  'Fatty acids, total monounsaturated',
#  'Fatty acids, total polyunsaturated',
#  'Carbohydrate, by difference',
#  'Fiber, total dietary',
#  'Sugars, total',
#  'Protein',
#  'Cholesterol',
#  'Sodium, Na',
#  'Calcium, Ca',
#  'Magnesium, Mg',
#  'Potassium, K',
#  'Iron, Fe',
#  'Zinc, Zn',
#  'Phosphorus, P',
#  'Vitamin A, RAE',
#  'Vitamin C, total ascorbic acid',
#  'Thiamin',
#  'Riboflavin',
#  'Niacin',
#  'Vitamin B-6',
#  'Folate, DFE',
#  'Folate, food',
#  'Folic acid',
#  'Vitamin B-12',
#  'Vitamin D (D2 + D3)',
#  'Vitamin E (alpha-tocopherol)',
#  'Vitamin K (phylloquinone)',
#  'Water']

# %%
nutrient_quantities
# Out:
# [470.0,
#  14.24,
#  3.266,
#  3.9050000000000002,
#  4.1930000000000005,
#  51.88,
#  9.1,
#  0.05,
#  31.97,
#  55.0,
#  61.0,
#  46.0,
#  109.0,
#  753.0,
#  3.6399999999999997,
#  1.9700000000000002,
#  423.0,
#  0.0,
#  3.9,
#  0.614,
#  0.22699999999999998,
#  10.653,
#  0.798,
#  272.0,
#  178.0,
#  55.0,
#  3.23,
#  0.0,
#  3.59,
#  0.5,
#  199.07]

# %%
nutrient_units
# Out:
# ['kcal',
#  'g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'g',
#  'mg',
#  'mg',
#  'mg',
#  'mg',
#  'mg',
#  'mg',
#  'mg',
#  'mg',
#  'µg',
#  'mg',
#  'mg',
#  'mg',
#  'mg',
#  'mg',
#  'µg',
#  'µg',
#  'µg',
#  'µg',
#  'µg',
#  'mg',
#  'µg',
#  'g']

# %% [markdown]
# # Creating our Data Frame

# %%
import pandas as pd

# %%
# Creating a data frame to store our recipe nutrient information

recipe_data = pd.DataFrame()

# %%
# Adding our lists of labels, quantities, and units
recipe_data["Label"] = nutrient_labels
recipe_data["Quantity"] = nutrient_quantities
recipe_data["Unit"] = nutrient_units

# %%
# Taking a look at our Data Frame
recipe_data
# Out:
#                                  Label  Quantity  Unit
# 0                               Energy   470.000  kcal
# 1                    Total lipid (fat)    14.240     g
# 2         Fatty acids, total saturated     3.266     g
# 3   Fatty acids, total monounsaturated     3.905     g
# 4   Fatty acids, total polyunsaturated     4.193     g
# 5          Carbohydrate, by difference    51.880     g
# 6                 Fiber, total dietary     9.100     g
# 7                        Sugars, total     0.050     g
# 8                              Protein    31.970     g
# 9                          Cholesterol    55.000    mg
# 10                          Sodium, Na    61.000    mg
# 11                         Calcium, Ca    46.000    mg
# 12                       Magnesium, Mg   109.000    mg
# 13                        Potassium, K   753.000    mg
# 14                            Iron, Fe     3.640    mg
# 15                            Zinc, Zn     1.970    mg
# 16                       Phosphorus, P   423.000    mg
# 17                      Vitamin A, RAE     0.000    µg
# 18      Vitamin C, total ascorbic acid     3.900    mg
# 19                             Thiamin     0.614    mg
# 20                          Riboflavin     0.227    mg
# 21                              Niacin    10.653    mg
# 22                         Vitamin B-6     0.798    mg
# 23                         Folate, DFE   272.000    µg
# 24                        Folate, food   178.000    µg
# 25                          Folic acid    55.000    µg
# 26                        Vitamin B-12     3.230    µg
# 27                 Vitamin D (D2 + D3)     0.000    µg
# 28        Vitamin E (alpha-tocopherol)     3.590    mg
# 29           Vitamin K (phylloquinone)     0.500    µg
# 30                               Water   199.070     g

# %% [markdown]
# # Saving our Data

# %%
recipe_data.to_csv('EDAMAM_API_Nutrient_Data.csv', index=False, encoding='utf-8')
